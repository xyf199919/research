# %%
# %config IPCompleter.greedy=True
# %matplotlib inline


import torch
import os
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import itertools
import math
import pandas as pd
import unicodedata
import codecs
import itertools



import matplotlib
import numpy as np
import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
import numpy as np

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

CUDA = torch.cuda.is_available()
# device = torch.device("cuda" if CUDA else "cpu")
device = torch.device("cuda")

# %% [markdown]
# # DATA

# %% [markdown]
# leave out validation set

# %%
INPUT_SIZE = 2500


xy = pd.read_csv('./prep_student_input.csv')
z = pd.read_csv('./word_translations.csv')

translations = {z['Italian'][i]: z['English'][i] for i in range(len(z))}


# pastconvo = [xy['Prep'][randomindexes[i]]+' '+xy['Obj'][randomindexes[i]] +' '+ xy['Color'][randomindexes[i]] +' '+ xy['Past Convo'][randomindexes[i]] for i in range(len(randomindexes))]
pastconvo = [xy['Past Convo'][i] for i in range(len(xy))]

response = [xy['Tutor Response'][i] for i in range(len(xy))]


#' '.join(pastconvo[i].split()[TOKENS_TAKEN:])
pairs = [[pastconvo[i], response[i]] for i in range(len(pastconvo))]

print("input data selected")
# Out:
# input data selected

# %% [markdown]
# # VOCABUOLARY

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Vocabulary:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold # CHANGE probably shouldn't do this
    def trim(self, min_count):
        keep_words = []
        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)        
        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))
        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %%
# make data simple
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# %%
# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# %% [markdown]
# # creating vocab

# %%
pairs = [[normalizeString(line) for line in p] for p in pairs]
pastconvo = [normalizeString(l) for l in pastconvo]
response = [normalizeString(l) for l in response]

voc = Vocabulary("dialog")

#getting  rid of rare words
for pair in pairs:
    voc.addSentence(pair[0])
    voc.addSentence(pair[1])
print("counted words:", voc.num_words)
print("vocabulary created")
# Out:
# counted words: 1014
# vocabulary created

# %% [markdown]
# # prepare data

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]

# %%
#make column consistent and transpose
def zeroPadding(l, fillvalue= 0):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

# %%
def binaryMatrix(l, value=0):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# %%
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.ByteTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len, input_batch, output_batch

# %% [markdown]
# # MODEL

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Attention using dot

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        self.hidden_size = hidden_size

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        attn_energies = self.dot_score(hidden, encoder_outputs)
        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()
        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# # EVAL

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to(device)
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words, scores


#returns a list of output words fiven a input sentence
def evaluateInput(encoder, decoder, searcher, voc, input_sentence, max_length):
    input_sentence = normalizeString(input_sentence)
    # Evaluate sentence
    output_words, scores = evaluate(encoder, decoder, searcher, voc, input_sentence, max_length)
    # Format and print response sentence
    output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
    return output_words, scores
#     print('Bot:', ' '.join(output_words))

def evaluate_with_target(encoder, decoder, searcher, voc, TEST_SIZE, INPUT_SIZE):

    randomindexes = [random.randint(INPUT_SIZE, len(xy['Past Convo'])) for _ in range(TEST_SIZE)]

    inputs = [xy['Past Convo'][randomindexes[i]] for i in range(TEST_SIZE)]
    targets = [xy['Tutor Response'][randomindexes[i]] for i in range(TEST_SIZE)]

    for i in range(TEST_SIZE):
        max_length = len(normalizeString(targets[i]).split()) 
        print("past convo:", inputs[i])
        print("\n")

        output_words, scores = evaluateInput(encoder, decoder, searcher, voc, inputs[i], max_target_len)
        print('Bot:', ' '.join(output_words))
        print("\n")
        print("Correct: ", targets[i])
        print("\n")
        
def validation_eval(encoder, decoder, searcher, voc, TEST_SIZE, INPUT_SIZE):

    randomindexes = [random.randint(INPUT_SIZE, len(xy['Past Convo'])) for _ in range(TEST_SIZE)]

    inputs = [xy['Past Convo'][randomindexes[i]] for i in range(TEST_SIZE)]
    targets = [xy['Tutor Response'][randomindexes[i]] for i in range(TEST_SIZE)]
    
    scores = []  
    for i in range(TEST_SIZE):
        max_length = len(normalizeString(targets[i]).split()) 
        print("past convo:", inputs[i])
        print("\n")

        output_words, scorelist = evaluateInput(encoder, decoder, searcher, voc, inputs[i], max_target_len)
        scores.append(sum(scorelist)/len(scorelist))
        print('Bot:', ' '.join(output_words))
        print("\n")
        
    return sum(scores)/len(scores)

# %% [markdown]
# # simulated student

# %%
import  pprint
pp = pprint.PrettyPrinter(indent = 4)


z = pd.read_csv('./word_translations.csv')
translations = {z['Italian'][i]: z['English'][i] for i in range(len(z))}
translations_toItalian = {z['English'][i]: z['Italian'][i] for i in range(len(z))}

concepts = list(translations.keys())
prep = concepts[:8]
color = concepts[8:16]
obj = concepts[16:]

def concept(word):
    if iseng(word):
        return translations_toItalian[word]
    else:
        return word

def iseng(word):
    if word in translations_toItalian.keys():
        return True
    else:
        return False

def isitalian(word):
    if word in translations.keys():
        return True
    else:
        return False

#guess is list in correct order, correct is solution list
def identify_incorrects(guess, correct):
    rv = []
    for i in range(len(correct)):
        if guess[i] != correct[i]:
            rv.append(correct[i])
    return rv

# %%
#correct order is prep obj color


class Student:
    def __init__(self, pickup, forget):
        global prep,color,obj
        self.pickup = pickup
        self.forget = forget
        self.knowledge = {
            "prep": {p: random.random() for p in prep},
            "color": {c: random.random() for c in color},
            "obj": {o: random.random() for o in obj}
        }
       
    #TODO: can output random italian word too
    #output three words in correct order list
    def guess(self, correct):
        global translations
        #correct: [prep, object, color]
        prep_c, obj_c, color_c = correct
        prep_t = translations[prep_c]
        obj_t = translations[obj_c]
        color_t = translations[color_c]
        
#         rv = 'is it '
        rv = []
        rv.append(prep_c) if self.knowledge["prep"][prep_c] > 0.7 else rv.append(prep_t)
        rv.append(obj_c)  if self.knowledge["obj"][obj_c] > 0.7 else rv.append(obj_t)
        rv.append(color_c) if self.knowledge["color"][color_c] > 0.7 else rv.append(color_t)
        return rv
    
    #returns empty string if nothing to ask
    #returns the eng word
    def ask(self, correct):
        #TODO: randomize order
        #correct = [prep_c, obj_c, color_c]
        global translations
        word = ''
        prep_c, obj_c, color_c = correct
        
        if self.knowledge["prep"][prep_c] < 0.3:
            word = prep_c
        elif self.knowledge["obj"][obj_c] <  0.3:
            word = obj_c
        elif self.knowledge["color"][color_c] < 0.3:
            word = color_c
        
        if word != '':
            #rv = 'How do i say ' + translations[word] + ' in Italian'
            rv = translations[word]
        else:
            rv = ''
        return rv
    #forgets concepts that is not mentioned for each tutor response, excluding  gained
#     def forget(self, gained):
        
    def pickout_concepts(self, output_words):
        #return all concepts (only in italian)
        rv = []
        for word in output_words:
            if isitalian(word):
                rv.append(word)
            elif iseng(word):
                rv.append(concept(word))
        return list(set(rv))
    
    def pickout_relevent_concepts(self, output_words, correct):
        #all concepts in italian
        concepts = self.pickout_concepts(output_words)
        return [x for x in concepts if x in correct]
                
    def change_knowledge(self, output_words, correct):
        #pick out knowledge
        global prep,color,obj
        concepts = self.pickout_relevent_concepts(output_words, correct)
        p = []
        o = []
        c=  []
        for word in concepts:
            if word in prep:
                p.append(word)
            elif word in color:
                c.append(word)
            elif word in obj:
                o.append(word)
        order = ["prep", "obj", "color"]  
        groups = [p, o, c]
        change = 0
        
        #update knowledge and return change
        #TODO only forget things that are not mentioned 
        for i in range(3):
            for c in groups[i]:
                if self.knowledge[order[i]][c] < 1:
                    self.knowledge[order[i]][c] = 1
                    change +=1
#                     if random.random() < self.pickup: 
#                         self.knowledge[order[i]][c] = min(self.knowledge[order[i]][c]+0.4, 1)
#                         change += 1   

        return change

# %%
def penalty(output_words, student, studentexpect, correct, incorrects):
    concepts = student.pickout_concepts(output_words)
    relevent = student.pickout_relevent_concepts(output_words, correct)
    #TODO relevent includes english and italian
    
    #if nothing correct but confirmed could be because ordering or grammar
    
    #conditional on student answer
    # 1 => penalize
    # 0 => reward
    
    #incorrect = list incorrect concepts in italian
    if len(incorrects) == 0 and studentexpect == '':
        if 'correct' not in output_words or 'yes' not in output_words:
            print("penalize: student was correct but no confirmation")
            return 1
        else:
            print("reward: correct")
            return 0.2
    elif studentexpect != '':
        #TODO need both eng and italian 
        if studentexpect in relevent:
            print("reward: answered question")
            return 0.2
        else:
            print("penalize: didn't answer question")
            return 1
    else:
        #the student made a guess that's incorrect 
        if len(incorrects) == 3 and 'correct' in output_words:
            print("penalize: all wrong but said correct")
            return 1
        if concepts == []:
            #maybe made a grammar hint
            print("neutral: did not make a word hint")
            return 0.8
        elif len(concepts) != len(relevent):
            print("penalize: had irrelevent hints")
            return 1
        else:
            #needs to be a hint that student got incorrect
            for hint in relevent:
                if hint not in incorrects:
                    print("penalize: not a hint that student got wrong")
                    return 1
            print("reward: is a hint student got wrong")
            return 0.2

# %%
# start one eval
def simulate_with_student(encoder, decoder, searcher, voc):
# one conversation
    student = Student(1,0)
    tutor_score = 0
    studentexpect = ''
    guess_incorrects = []
    prep_c =  random.choice(prep)
    color_c = random.choice(color)
    obj_c = random.choice(obj)
    correct = [prep_c, obj_c, color_c]
    print(correct)
    
    #TODO: while student not correct or expects answer
    for i in range(10):
        coin = random.random()
        if coin < 0.5 and student.ask(correct) != '':
            askeng = student.ask(correct)
            studentexpect = translations_toItalian[askeng]
            input_sent = 'How do you say ' + askeng + ' in Italian'
        else:
            guess = student.guess(correct)
            guess_incorrects = identify_incorrects(guess, correct)
            input_sent = "is it "+ guess[0] + " " + guess[1] + " " + guess[2]
        
#         print('\n')
#         print('Student:', input_sent)
#         print('incorrect:', guess_incorrects)
#         print('expect:', studentexpect)

        #evaluate on model
        output_words,scores = evaluateInput(encoder, decoder, searcher, voc, input_sent, max_target_len)
        output = ' '.join(output_words)
        #evaluate on input
#         output = input('> ')
#         if output == 'q' or output == 'quit': break
#         output_words = output.split()
        
        #how many concpets changed
        change = student.change_knowledge(output_words, correct)
        
        #change tutor score
        tutor_score += penalty(output_words, student, studentexpect, correct, guess_incorrects)

        print('Bot:', output)
#         print('pickout concpets:', student.pickout_concepts(output_words))
#         print('change:', change)
        #TODO: tutor_score
        print('penalty', tutor_score)  
        studentexpect = ''
        guess_incorrects = []
        
    return tutor_score

# %% [markdown]
# # test train with input

# %%
#simulate_with_student(encoder, decoder, searcher, voc)
# simulate_with_student(voc)

# %% [markdown]
# # TRAIN

# %%
# negative log lokelihood loss
# maskNLLLoss(decoder_output, target_variable[t], mask[t])
def maskNLLLoss(inp, target, mask): 
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    #loss = reward * loss -> 0.001/1
#     loss = loss * tutor_score
    loss = loss.to(device)
    return loss, nTotal.item()

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip, i):
    
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_variable = input_variable.to(device)
    lengths = lengths.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)

    loss = 0
    print_losses = []
    n_totals = 0


    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)
#     print("encoder output shape", encoder_outputs.shape)
#     print("last encoder hidden shape", encoder_hidden.shape)

    decoder_input = torch.LongTensor([[SOS_token for _ in range (small_batch_size)]])
    decoder_input = decoder_input.to(device)
#     print("initial decoder input shape", decoder_input.shape)
#     print(decoder_input)

    decoder_hidden =  encoder_hidden[:decoder.n_layers]
#     print("initial decoder hidden state shape", decoder_hidden.shape)
    for t in range(max_target_len):
        decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden, encoder_outputs)

        #teacher forcing
        decoder_input = target_variable[t].view(1,-1)

        mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
        loss += mask_loss
        print_losses.append(mask_loss.item() * nTotal)

        n_totals += nTotal
        
#     if iteration > 100 and iteration % 20 == 0:
    encoder.eval()
    decoder.eval()

    searcher = GreedySearchDecoder(encoder, decoder)
    tutor_score = simulate_with_student(encoder, decoder, searcher, voc)
    encoder.train()
    decoder.train()

    loss = loss * tutor_score / 10
    returned_loss = sum(print_losses) / n_totals * tutor_score / 10
#     else:
#         returned_loss = sum(print_losses) / n_totals
    
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()
    
    print("training loss", returned_loss)
#     print(returned_losses)
    print("\n")

    return returned_loss, tutor_score

# %%
def valid(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip):
    
    input_variable = input_variable.to(device)
    lengths = lengths.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)

    loss = 0
    print_losses = []
    n_totals = 0

    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)
#     print("encoder output shape", encoder_outputs.shape)
#     print("last encoder hidden shape", encoder_hidden.shape)

    decoder_input = torch.LongTensor([[SOS_token for _ in range (small_batch_size)]])
    decoder_input = decoder_input.to(device)
#     print("initial decoder input shape", decoder_input.shape)
#     print(decoder_input)

    decoder_hidden =  encoder_hidden[:decoder.n_layers]
#     print("initial decoder hidden state shape", decoder_hidden.shape)
    for t in range(max_target_len):
        decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden, encoder_outputs)

        #teacher forcing
        decoder_input = target_variable[t].view(1,-1)

        mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
        loss += mask_loss
        print_losses.append(mask_loss.item() * nTotal)

        n_totals += nTotal
    
    returned_loss = sum(print_losses) / n_totals
    
    print("validation loss", returned_loss)
#     print(returned_losses)
    print("\n")

    return returned_loss

# %%
    
LEARN_RATE = 0.001
clip = 50.0
# num_iters = 400
DESIRED_LOSS = 0.1

small_batch_size = 30
# batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
# input_variable, lengths, target_variable, mask, max_target_len, input_batch, output_batch = batches

# print("input_variable:", input_variable)
# print("lengths:", lengths)
# print("target_variable:", target_variable)
# print("mask:", mask)
# print("max_target_len:", max_target_len)

attn_model = 'dot'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
embedding = nn.Embedding(voc.num_words, hidden_size)

encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model,  embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
#pass models to device 
encoder = encoder.to(device)
decoder = decoder.to(device)

encoder.train()
decoder.train()

#optimizers
encoder_optimizer = optim.Adam(encoder.parameters(), lr=LEARN_RATE)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=LEARN_RATE)
encoder_optimizer.zero_grad()
decoder_optimizer.zero_grad()



# start training
print("START TRAINING")
print("\n")

returned_losses = []
validation_losses = []
tutor_scores = []
searcher = GreedySearchDecoder(encoder, decoder)
TEST_SIZE = 30

#predefine eval set
randomindexes = [random.randint(INPUT_SIZE, len(pastconvo)) for _ in range(TEST_SIZE)]
evalset = [pairs[randomindexes[i]] for i in range(len(randomindexes))]


iteration = 0
# for iteration in range(num_iters):
while iteration < 1500:
    iteration += 1
    print(" Iteration:", iteration)
    
    randomindexes = [random.randint(0, INPUT_SIZE) for _ in range(small_batch_size)]
    trainset = [pairs[randomindexes[i]] for i in range(small_batch_size)]
    
    batches = batch2TrainData(voc, trainset)
    input_variable, lengths, target_variable, mask, max_target_len, input_batch, output_batch = batches
    
    #train one iter

    returned_loss, tutor_score = train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding, encoder_optimizer, decoder_optimizer, small_batch_size, iteration, clip)
    
    returned_losses.append(returned_loss)
    tutor_scores.append(tutor_score)
#     print(returned_losses)
    
    print("\n")
    
    if iteration % 20 == 0:
        encoder.eval()
        decoder.eval()
        
        
        evalbatches = batch2TrainData(voc, evalset)
        input_variable, lengths, target_variable, mask, max_target_len, input_batch, output_batch = evalbatches
        
        valid_loss = valid(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, small_batch_size, clip)
        encoder.train()
        decoder.train()
        
    if iteration >= 100:
        validation_losses.append(valid_loss)
    
    if iteration % 100 == 0:   
        plt.plot(returned_losses, color='blue')
        plt.plot(validation_losses, color='red')
        plt.plot(tutor_scores, color='green')
        plt.show()
# Out:
# START TRAINING
#
#
#  Iteration: 1
# ['cima', 'albero', 'blu']
# penalize: didn't answer question
# Bot: encima coniglio coniglio coniglio coniglio coniglio written vacino vacino give vacino coniglio coniglio coniglio coniglio written vacino vacino give vacino coniglio coniglio coniglio coniglio written vacino vacino
# penalty 1
# penalize: didn't answer question
# Bot: encima coniglio coniglio coniglio coniglio coniglio written vacino vacino give vacino coniglio coniglio coniglio coniglio written vacino vacino give vacino coniglio coniglio coniglio coniglio written vacino vacino
# penalty 2
# neutral: did not make a word hint
# Bot: provided albeo cogniglio cogniglio see vacino vacino vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary
# penalty 2.8
# neutral: did not make a word hint
# Bot: provided albeo cogniglio cogniglio see vacino vacino vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary
# penalty 3.5999999999999996
# neutral: did not make a word hint
# Bot: provided albeo cogniglio cogniglio see vacino vacino vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary
# penalty 4.3999999999999995
# neutral: did not make a word hint
# Bot: provided albeo cogniglio cogniglio see vacino vacino vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary
# penalty 5.199999999999999
# neutral: did not make a word hint
# Bot: provided albeo cogniglio cogniglio see vacino vacino vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary
# penalty 5.999999999999999
# penalize: didn't answer question
# Bot: encima coniglio coniglio coniglio coniglio coniglio written vacino vacino give vacino coniglio coniglio coniglio coniglio written vacino vacino give vacino coniglio coniglio coniglio coniglio written vacino vacino
# penalty 6.999999999999999
# neutral: did not make a word hint
# Bot: provided albeo cogniglio cogniglio see vacino vacino vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary vacino vacino vacino unnecessary
# penalty 7.799999999999999
# penalize: didn't answer question
# Bot: encima coniglio coniglio coniglio coniglio coniglio written vacino vacino give vacino coniglio coniglio coniglio coniglio written vacino vacino give vacino coniglio coniglio coniglio coniglio written vacino vacino
# penalty 8.799999999999999
# training loss 6.088953293907841
#
#
#
#
#  Iteration: 2
# ['cima', 'tavolo', 'rosa']
# penalize: didn't answer question
# Bot: .
# penalty 1
# neutral: did not make a word hint
# Bot:
# penalty 1.8
# penalize: didn't answer question
# Bot: .
# penalty 2.8
# penalize: didn't answer question
# Bot: .
# penalty 3.8
# penalize: didn't answer question
# Bot: .
# penalty 4.8
# penalize: didn't answer question
# Bot: .
# penalty 5.8
# neutral: did not make a word hint
# Bot:
# penalty 6.6
# neutral: did not make a word hint
# Bot:
# penalty 7.3999999999999995
# penalize: didn't answer question
# Bot: .
# penalty 8.399999999999999
# neutral: did not make a word hint
# Bot:
# penalty 9.2
# training loss 6.25120192667333
#
#
#
#
#  Iteration: 3
# ['dietro', 'cane', 'gialla']
# neutral: did not make a word hint
# Bot:
# penalty 0.8
# neutral: did not make a word hint
# Bot:
# penalty 1.6
# neutral: did not make a word hint
# Bot:
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot:
# penalty 3.2
# neutral: did not make a word hint
# Bot:
# penalty 4.0
# neutral: did not make a word hint
# Bot:
# penalty 4.8
# neutral: did not make a word hint
# Bot:
# penalty 5.6
# neutral: did not make a word hint
# Bot:
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot:
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot:
# penalty 7.999999999999999
# training loss 4.849226760864257
#
#
#
#
#  Iteration: 4
# ['accanto', 'coniglio', 'blu']
# neutral: did not make a word hint
# Bot:
# penalty 0.8
# neutral: did not make a word hint
# Bot:
# penalty 1.6
# neutral: did not make a word hint
# Bot:
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot:
# penalty 3.2
# neutral: did not make a word hint
# Bot:
# penalty 4.0
# neutral: did not make a word hint
# Bot:
# penalty 4.8
# penalize: didn't answer question
# Bot:
# penalty 5.8
# penalize: didn't answer question
# Bot:
# penalty 6.8
# penalize: didn't answer question
# Bot:
# penalty 7.8
# neutral: did not make a word hint
# Bot:
# penalty 8.6
# training loss 4.929738011853448
#
#
#
#
#  Iteration: 5
# ['cima', 'letto', 'viola']
# penalize: didn't answer question
# Bot: .
# penalty 1
# penalize: didn't answer question
# Bot: .
# penalty 2
# penalize: didn't answer question
# Bot: .
# penalty 3
# penalize: didn't answer question
# Bot: .
# penalty 4
# penalize: didn't answer question
# Bot: .
# penalty 5
# penalize: didn't answer question
# Bot: .
# penalty 6
# neutral: did not make a word hint
# Bot: .
# penalty 6.8
# neutral: did not make a word hint
# Bot: .
# penalty 7.6
# neutral: did not make a word hint
# Bot: .
# penalty 8.4
# penalize: didn't answer question
# Bot: .
# penalty 9.4
# training loss 4.986385966102745
#
#
#
#
#  Iteration: 6
# ['dentro', 'gatto', 'rossa']
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 0.8
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 1.6
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 3.2
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 4.0
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 4.8
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 5.6
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 7.999999999999999
# training loss 4.136572954987966
#
#
#
#
#  Iteration: 7
# ['accanto', 'cane', 'giallo']
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 1
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 2
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 3
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 4
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 5
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 6
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 7
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 8
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 9
# penalize: student was correct but no confirmation
# Bot: the the the the the the the the the the the the the the the the the the the the the the the
# penalty 10
# training loss 4.848113548408434
#
#
#
#
#  Iteration: 8
# ['accanto', 'tavolo', 'gialla']
# neutral: did not make a word hint
# Bot: .
# penalty 0.8
# neutral: did not make a word hint
# Bot: .
# penalty 1.6
# penalize: didn't answer question
# Bot: is is .
# penalty 2.6
# penalize: didn't answer question
# Bot: is is .
# penalty 3.6
# neutral: did not make a word hint
# Bot: .
# penalty 4.4
# neutral: did not make a word hint
# Bot: .
# penalty 5.2
# neutral: did not make a word hint
# Bot: .
# penalty 6.0
# neutral: did not make a word hint
# Bot: .
# penalty 6.8
# penalize: didn't answer question
# Bot: is is .
# penalty 7.8
# neutral: did not make a word hint
# Bot: .
# penalty 8.6
# training loss 4.217194329855834
#
#
#
#
#  Iteration: 9
# ['vicino', 'borsa', 'rosso']
# penalize: didn't answer question
# Bot: is is .
# penalty 1
# penalize: didn't answer question
# Bot: is is .
# penalty 2
# neutral: did not make a word hint
# Bot: .
# penalty 2.8
# penalize: didn't answer question
# Bot: is is .
# penalty 3.8
# neutral: did not make a word hint
# Bot: .
# penalty 4.6
# neutral: did not make a word hint
# Bot: .
# penalty 5.3999999999999995
# neutral: did not make a word hint
# Bot: .
# penalty 6.199999999999999
# penalize: didn't answer question
# Bot: is is .
# penalty 7.199999999999999
# penalize: didn't answer question
# Bot: is is .
# penalty 8.2
# penalize: didn't answer question
# Bot: is is .
# penalty 9.2
# training loss 4.361927188061877
#
#
#
#
#  Iteration: 10
# ['sotto', 'albero', 'rosa']
# neutral: did not make a word hint
# Bot: .
# penalty 0.8
# neutral: did not make a word hint
# Bot: .
# penalty 1.6
# penalize: didn't answer question
# Bot: .
# penalty 2.6
# neutral: did not make a word hint
# Bot: .
# penalty 3.4000000000000004
# neutral: did not make a word hint
# Bot: .
# penalty 4.2
# penalize: didn't answer question
# Bot: .
# penalty 5.2
# penalize: didn't answer question
# Bot: .
# penalty 6.2
# penalize: didn't answer question
# Bot: .
# penalty 7.2
# neutral: did not make a word hint
# Bot: .
# penalty 8.0
# neutral: did not make a word hint
# Bot: .
# penalty 8.8
# training loss 4.0027726459503175
#
#
#
#
#  Iteration: 11
# ['dentro', 'tavolo', 'verde']
# penalize: didn't answer question
# Bot: .
# penalty 1
# penalize: didn't answer question
# Bot: .
# penalty 2
# penalize: didn't answer question
# Bot: .
# penalty 3
# neutral: did not make a word hint
# Bot: .
# penalty 3.8
# penalize: didn't answer question
# Bot: .
# penalty 4.8
# penalize: didn't answer question
# Bot: .
# penalty 5.8
# penalize: didn't answer question
# Bot: .
# penalty 6.8
# penalize: didn't answer question
# Bot: .
# penalty 7.8
# neutral: did not make a word hint
# Bot: .
# penalty 8.6
# penalize: didn't answer question
# Bot: .
# penalty 9.6
# training loss 4.394359710897718
#
#
#
#
#  Iteration: 12
# ['fronte', 'cane', 'viola']
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 0.8
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 1.6
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 3.2
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 4.0
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 4.8
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 5.6
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: the the the the the the the
# penalty 7.999999999999999
# training loss 3.8355706181222375
#
#
#
#
#  Iteration: 13
# ['fronte', 'albero', 'viola']
# neutral: did not make a word hint
# Bot: the the the the the the ?
# penalty 0.8
# neutral: did not make a word hint
# Bot: the the the the the the ?
# penalty 1.6
# neutral: did not make a word hint
# Bot: the the the the the the ?
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: the the the the the the ?
# penalty 3.2
# penalize: didn't answer question
# Bot: is is the word ?
# penalty 4.2
# penalize: didn't answer question
# Bot: is is the word ?
# penalty 5.2
# penalize: didn't answer question
# Bot: is is the word ?
# penalty 6.2
# neutral: did not make a word hint
# Bot: the the the the the the ?
# penalty 7.0
# penalize: didn't answer question
# Bot: is is the word ?
# penalty 8.0
# neutral: did not make a word hint
# Bot: the the the the the the ?
# penalty 8.8
# training loss 4.0289431976056305
#
#
#
#
#  Iteration: 14
# ['davanti', 'albero', 'rosa']
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 0.8
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 1.6
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 3.2
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 4.0
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 4.8
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 5.6
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: is the the the .
# penalty 7.999999999999999
# training loss 3.6575345473606498
#
#
#
#
#  Iteration: 15
# ['sotto', 'tavolo', 'verde']
# neutral: did not make a word hint
# Bot: .
# penalty 0.8
# neutral: did not make a word hint
# Bot: .
# penalty 1.6
# neutral: did not make a word hint
# Bot: .
# penalty 2.4000000000000004
# penalize: didn't answer question
# Bot: is is .
# penalty 3.4000000000000004
# penalize: didn't answer question
# Bot: is is .
# penalty 4.4
# neutral: did not make a word hint
# Bot: .
# penalty 5.2
# neutral: did not make a word hint
# Bot: .
# penalty 6.0
# neutral: did not make a word hint
# Bot: .
# penalty 6.8
# penalize: didn't answer question
# Bot: is is .
# penalty 7.8
# neutral: did not make a word hint
# Bot: .
# penalty 8.6
# training loss 3.9905440317645016
#
#
#
#
#  Iteration: 16
# ['cima', 'tavolo', 'blu']
# neutral: did not make a word hint
# Bot: is . . . . . . . . .
# penalty 0.8
# neutral: did not make a word hint
# Bot: is . . . . . . . . .
# penalty 1.6
# penalize: didn't answer question
# Bot: is is .
# penalty 2.6
# neutral: did not make a word hint
# Bot: is . . . . . . . . .
# penalty 3.4000000000000004
# neutral: did not make a word hint
# Bot: is . . . . . . . . .
# penalty 4.2
# penalize: didn't answer question
# Bot: is is .
# penalty 5.2
# penalize: didn't answer question
# Bot: is is .
# penalty 6.2
# penalize: didn't answer question
# Bot: is is .
# penalty 7.2
# penalize: didn't answer question
# Bot: is is .
# penalty 8.2
# penalize: didn't answer question
# Bot: is is .
# penalty 9.2
# training loss 4.103103719013992
#
#
#
#
#  Iteration: 17
# ['dentro', 'albero', 'rosa']
# neutral: did not make a word hint
# Bot: is is . . you the the the the word ?
# penalty 0.8
# penalize: didn't answer question
# Bot: is is .
# penalty 1.8
# penalize: didn't answer question
# Bot: is is .
# penalty 2.8
# penalize: didn't answer question
# Bot: is is .
# penalty 3.8
# penalize: didn't answer question
# Bot: is is .
# penalty 4.8
# neutral: did not make a word hint
# Bot: is is . . you the the the the word ?
# penalty 5.6
# penalize: didn't answer question
# Bot: is is .
# penalty 6.6
# penalize: didn't answer question
# Bot: is is .
# penalty 7.6
# penalize: didn't answer question
# Bot: is is .
# penalty 8.6
# neutral: did not make a word hint
# Bot: is is . . you the the the the word ?
# penalty 9.4
# training loss 4.327954850374691
#
#
#
#
#  Iteration: 18
# ['cima', 'albero', 'rossa']
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 0.8
# penalize: didn't answer question
# Bot: is the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 1.8
# penalize: didn't answer question
# Bot: is the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 2.8
# penalize: didn't answer question
# Bot: is the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 3.8
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 4.6
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 5.3999999999999995
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 6.199999999999999
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 6.999999999999999
# penalize: didn't answer question
# Bot: is the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 7.999999999999999
# penalize: didn't answer question
# Bot: is the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# penalty 9.0
# training loss 4.100841262340546
#
#
#
#
#  Iteration: 19
# ['sotto', 'albero', 'blu']
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the . . you the the the the the the the the the the
# penalty 0.8
# penalize: didn't answer question
# Bot: is the the the the the the ?
# penalty 1.8
# penalize: didn't answer question
# Bot: is the the the the the the ?
# penalty 2.8
# penalize: didn't answer question
# Bot: is the the the the the the ?
# penalty 3.8
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the . . you the the the the the the the the the the
# penalty 4.6
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the . . you the the the the the the the the the the
# penalty 5.3999999999999995
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the . . you the the the the the the the the the the
# penalty 6.199999999999999
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the . . you the the the the the the the the the the
# penalty 6.999999999999999
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the . . you the the the the the the the the the the
# penalty 7.799999999999999
# neutral: did not make a word hint
# Bot: the the the the the the the the the the the the . . you the the the the the the the the the the
# penalty 8.6
# training loss 3.92022462239019
#
#
#
#
#  Iteration: 20
# ['dietro', 'albero', 'gialla']
# neutral: did not make a word hint
# Bot: you you the the the the ?
# penalty 0.8
# penalize: didn't answer question
# Bot: to to to the the the the ?
# penalty 1.8
# penalize: didn't answer question
# Bot: to to to the the the the ?
# penalty 2.8
# neutral: did not make a word hint
# Bot: you you the the the the ?
# penalty 3.5999999999999996
# neutral: did not make a word hint
# Bot: you you the the the the ?
# penalty 4.3999999999999995
# neutral: did not make a word hint
# Bot: you you the the the the ?
# penalty 5.199999999999999
# neutral: did not make a word hint
# Bot: you you the the the the ?
# penalty 5.999999999999999
# neutral: did not make a word hint
# Bot: you you the the the the ?
# penalty 6.799999999999999
# neutral: did not make a word hint
# Bot: you you the the the the ?
# penalty 7.599999999999999
# neutral: did not make a word hint
# Bot: you you the the the the ?
# penalty 8.399999999999999
# training loss 3.944861579557744
#
#
#
#
# validation loss 4.489893277719224
#
#
#  Iteration: 21
# ['dentro', 'tavolo', 'rosso']
# penalize: didn't answer question
# Bot: to to to to to to to the to to to to the to to to to the to to to to the to
# penalty 1
# penalize: didn't answer question
# Bot: to to to to to to to the to to to to the to to to to the to to to to the to
# penalty 2
# penalize: didn't answer question
# Bot: to to to to to to to the to to to to the to to to to the to to to to the to
# penalty 3
# penalize: didn't answer question
# Bot: to to to to to to to the to to to to the to to to to the to to to to the to
# penalty 4
# penalize: didn't answer question
# Bot: to to to to to to to the to to to to the to to to to the to to to to the to
# penalty 5
# neutral: did not make a word hint
# Bot: you you to to the to the to the ? you you to to the ? you you
# penalty 5.8
# neutral: did not make a word hint
# Bot: you you to to the to the to the ? you you to to the ? you you
# penalty 6.6
# penalize: didn't answer question
# Bot: to to to to to to to the to to to to the to to to to the to to to to the to
# penalty 7.6
# neutral: did not make a word hint
# Bot: you you to to the to the to the ? you you to to the ? you you
# penalty 8.4
# penalize: didn't answer question
# Bot: to to to to to to to the to to to to the to to to to the to to to to the to
# penalty 9.4
# training loss 4.1543089465815575
#
#
#
#
#  Iteration: 22
# ['davanti', 'scatola', 'rosso']
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 0.8
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 1.6
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 3.2
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 4.0
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 4.8
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 5.6
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: you you to the the ? you you to the ? you you to the ? you you
# penalty 7.999999999999999
# training loss 3.291405572642141
#
#
#
#
#  Iteration: 23
# ['fronte', 'gatto', 'rossa']
# neutral: did not make a word hint
# Bot: is . you you the ? you you the ? you you to the ? you you to the ?
# penalty 0.8
# neutral: did not make a word hint
# Bot: is . you you the ? you you the ? you you to the ? you you to the ?
# penalty 1.6
# penalize: didn't answer question
# Bot:
# penalty 2.6
# neutral: did not make a word hint
# Bot: is . you you the ? you you the ? you you to the ? you you to the ?
# penalty 3.4000000000000004
# penalize: didn't answer question
# Bot:
# penalty 4.4
# neutral: did not make a word hint
# Bot: is . you you the ? you you the ? you you to the ? you you to the ?
# penalty 5.2
# penalize: didn't answer question
# Bot:
# penalty 6.2
# neutral: did not make a word hint
# Bot: is . you you the ? you you the ? you you to the ? you you to the ?
# penalty 7.0
# neutral: did not make a word hint
# Bot: is . you you the ? you you the ? you you to the ? you you to the ?
# penalty 7.8
# neutral: did not make a word hint
# Bot: is . you you the ? you you the ? you you to the ? you you to the ?
# penalty 8.6
# training loss 4.01750121665212
#
#
#
#
#  Iteration: 24
# ['vicino', 'coniglio', 'giallo']
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 0.8
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 1.6
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 3.2
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 4.0
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 4.8
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 5.6
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: is . . you you is the ? . you you the ? try . . you you the ?
# penalty 7.999999999999999
# training loss 3.7703399129535833
#
#
#
#
#  Iteration: 25
# ['sotto', 'borsa', 'blu']
# penalize: didn't answer question
# Bot: is the word ?
# penalty 1
# penalize: didn't answer question
# Bot: is the word ?
# penalty 2
# penalize: didn't answer question
# Bot: is the word ?
# penalty 3
# neutral: did not make a word hint
# Bot: is . . is . . you is the the ? . you is the the
# penalty 3.8
# neutral: did not make a word hint
# Bot: is . . is . . you is the the ? . you is the the
# penalty 4.6
# penalize: didn't answer question
# Bot: is the word ?
# penalty 5.6
# neutral: did not make a word hint
# Bot: is . . is . . you is the the ? . you is the the
# penalty 6.3999999999999995
# penalize: didn't answer question
# Bot: is the word ?
# penalty 7.3999999999999995
# neutral: did not make a word hint
# Bot: is . . is . . you is the the ? . you is the the
# penalty 8.2
# neutral: did not make a word hint
# Bot: is . . is . . you is the the ? . you is the the
# penalty 9.0
# training loss 4.0803363641073185
#
#
#
#
#  Iteration: 26
# ['davanti', 'cane', 'viola']
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 0.8
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 1.6
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 3.2
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 4.0
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 4.8
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 5.6
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: is the the word word ? . . is the the noun .
# penalty 7.999999999999999
# training loss 3.479975202508792
#
#
#
#
#  Iteration: 27
# ['fronte', 'gatto', 'rossa']
# penalize: didn't answer question
# Bot: almost almost almost almost is e .
# penalty 1
# penalize: didn't answer question
# Bot: almost almost almost almost is e .
# penalty 2
# penalize: didn't answer question
# Bot: almost almost almost almost is e .
# penalty 3
# neutral: did not make a word hint
# Bot: is the the word word ? . is the the noun . . is the
# penalty 3.8
# neutral: did not make a word hint
# Bot: is the the word word ? . is the the noun . . is the
# penalty 4.6
# penalize: didn't answer question
# Bot: almost almost almost almost is e .
# penalty 5.6
# penalize: didn't answer question
# Bot: almost almost almost almost is e .
# penalty 6.6
# penalize: didn't answer question
# Bot: almost almost almost almost is e .
# penalty 7.6
# penalize: didn't answer question
# Bot: almost almost almost almost is e .
# penalty 8.6
# neutral: did not make a word hint
# Bot: is the the word word ? . is the the noun . . is the
# penalty 9.4
# training loss 3.9008050570518455
#
#
#
#
#  Iteration: 28
# ['dentro', 'scatola', 'rossa']
# penalize: didn't answer question
# Bot: the word word word for is the word ?
# penalty 1
# penalize: didn't answer question
# Bot: the word word word for is the word ?
# penalty 2
# neutral: did not make a word hint
# Bot: is the the word word for . try again . try . try . try . try . try . try .
# penalty 2.8
# penalize: didn't answer question
# Bot: the word word word for is the word ?
# penalty 3.8
# neutral: did not make a word hint
# Bot: is the the word word for . try again . try . try . try . try . try . try .
# penalty 4.6
# penalize: didn't answer question
# Bot: the word word word for is the word ?
# penalty 5.6
# penalize: didn't answer question
# Bot: the word word word for is the word ?
# penalty 6.6
# penalize: didn't answer question
# Bot: the word word word for is the word ?
# penalty 7.6
# neutral: did not make a word hint
# Bot: is the the word word for . try again . try . try . try . try . try . try .
# penalty 8.4
# penalize: didn't answer question
# Bot: the word word word for is the word ?
# penalty 9.4
# training loss 3.959802340777437
#
#
#
#
#  Iteration: 29
# ['davanti', 'cane', 'blu']
# neutral: did not make a word hint
# Bot: is the . you the word word ? . try . try . try . try . try . try . try . try . try
# penalty 0.8
# penalize: didn't answer question
# Bot: close is the . you say the word ?
# penalty 1.8
# penalize: didn't answer question
# Bot: close is the . you say the word ?
# penalty 2.8
# neutral: did not make a word hint
# Bot: is the . you the word word ? . try . try . try . try . try . try . try . try . try
# penalty 3.5999999999999996
# penalize: didn't answer question
# Bot: close is the . you say the word ?
# penalty 4.6
# neutral: did not make a word hint
# Bot: is the . you the word word ? . try . try . try . try . try . try . try . try . try
# penalty 5.3999999999999995
# neutral: did not make a word hint
# Bot: is the . you the word word ? . try . try . try . try . try . try . try . try . try
# penalty 6.199999999999999
# penalize: didn't answer question
# Bot: close is the . you say the word ?
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: is the . you the word word ? . try . try . try . try . try . try . try . try . try
# penalty 7.999999999999999
# neutral: did not make a word hint
# Bot: is the . you the word word ? . try . try . try . try . try . try . try . try . try
# penalty 8.799999999999999
# training loss 3.880648678209421
#
#
#
#
#  Iteration: 30
# ['vicino', 'tavolo', 'rossa']
# penalize: didn't answer question
# Bot: almost almost . you remember say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try
# penalty 1
# penalize: didn't answer question
# Bot: almost almost . you remember say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try
# penalty 2
# neutral: did not make a word hint
# Bot: almost is . you remember the word ? try again . try . try again . try . try again . try . try again . try . try again . try . try again . try . try again . try .
# penalty 2.8
# penalize: didn't answer question
# Bot: almost almost . you remember say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try
# penalty 3.8
# penalize: didn't answer question
# Bot: almost almost . you remember say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try
# penalty 4.8
# penalize: didn't answer question
# Bot: almost almost . you remember say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try
# penalty 5.8
# penalize: didn't answer question
# Bot: almost almost . you remember say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try
# penalty 6.8
# penalize: didn't answer question
# Bot: almost almost . you remember say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try
# penalty 7.8
# penalize: didn't answer question
# Bot: almost almost . you remember say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try
# penalty 8.8
# penalize: didn't answer question
# Bot: almost almost . you remember say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try again . you say ? try
# penalty 9.8
# training loss 4.175326139442623
#
#
#
#
#  Iteration: 31
# ['davanti', 'gatto', 'gialla']
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 0.8
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 1.6
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 3.2
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 4.0
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 4.8
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 5.6
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: the word word . try again . try . try . try again . try . try . try again . try . try . try again . try .
# penalty 7.999999999999999
# training loss 3.4305176671858755
#
#
#
#
#  Iteration: 32
# ['sotto', 'scatola', 'rosso']
# neutral: did not make a word hint
# Bot: the word . try again . try again . try again . try again . try again . try again . try again . try again .
# penalty 0.8
# neutral: did not make a word hint
# Bot: the word . try again . try again . try again . try again . try again . try again . try again . try again .
# penalty 1.6
# penalize: didn't answer question
# Bot: you say the word ? try again . try again . try again . try again . try again . try again . try again . try
# penalty 2.6
# penalize: didn't answer question
# Bot: you say the word ? try again . try again . try again . try again . try again . try again . try again . try
# penalty 3.6
# neutral: did not make a word hint
# Bot: the word . try again . try again . try again . try again . try again . try again . try again . try again .
# penalty 4.4
# penalize: didn't answer question
# Bot: you say the word ? try again . try again . try again . try again . try again . try again . try again . try
# penalty 5.4
# neutral: did not make a word hint
# Bot: the word . try again . try again . try again . try again . try again . try again . try again . try again .
# penalty 6.2
# penalize: didn't answer question
# Bot: you say the word ? try again . try again . try again . try again . try again . try again . try again . try
# penalty 7.2
# neutral: did not make a word hint
# Bot: the word . try again . try again . try again . try again . try again . try again . try again . try again .
# penalty 8.0
# neutral: did not make a word hint
# Bot: the word . try again . try again . try again . try again . try again . try again . try again . try again .
# penalty 8.8
# training loss 3.7906938518954147
#
#
#
#
#  Iteration: 33
# ['davanti', 'cane', 'blu']
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 0.8
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 1.6
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 3.2
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 4.0
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 4.8
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 5.6
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: you remember say the word ? try again . try again . try again
# penalty 7.999999999999999
# training loss 3.296802053698505
#
#
#
#
#  Iteration: 34
# ['davanti', 'scatola', 'rosa']
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 0.8
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 1.6
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 3.2
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 4.0
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 4.8
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 5.6
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: you say is the . try again . try again . try again . try again . try again . try again
# penalty 7.999999999999999
# training loss 3.274293675481902
#
#
#
#
#  Iteration: 35
# ['vicino', 'cane', 'gialla']
# neutral: did not make a word hint
# Bot: is the . you know to say ? try again . try again . try again . try again . try again .
# penalty 0.8
# penalize: didn't answer question
# Bot: you say ? try again . try again . try again . you say ? try again . try again . try
# penalty 1.8
# neutral: did not make a word hint
# Bot: is the . you know to say ? try again . try again . try again . try again . try again .
# penalty 2.6
# neutral: did not make a word hint
# Bot: is the . you know to say ? try again . try again . try again . try again . try again .
# penalty 3.4000000000000004
# penalize: didn't answer question
# Bot: you say ? try again . try again . try again . you say ? try again . try again . try
# penalty 4.4
# neutral: did not make a word hint
# Bot: is the . you know to say ? try again . try again . try again . try again . try again .
# penalty 5.2
# neutral: did not make a word hint
# Bot: is the . you know to say ? try again . try again . try again . try again . try again .
# penalty 6.0
# neutral: did not make a word hint
# Bot: is the . you know to say ? try again . try again . try again . try again . try again .
# penalty 6.8
# penalize: didn't answer question
# Bot: you say ? try again . try again . try again . you say ? try again . try again . try
# penalty 7.8
# neutral: did not make a word hint
# Bot: is the . you know to say ? try again . try again . try again . try again . try again .
# penalty 8.6
# training loss 3.836765390048073
#
#
#
#
#  Iteration: 36
# ['dietro', 'letto', 'verde']
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 0.8
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 1.6
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 3.2
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 4.0
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 4.8
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 5.6
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: is . you say ? try . try . try . try . try . try . try . try . try . try
# penalty 7.999999999999999
# training loss 3.160155368209243
#
#
#
#
#  Iteration: 37
# ['cima', 'tavolo', 'rosso']
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 0.8
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 1.6
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 3.2
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 4.0
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 4.8
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 5.6
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try .
# penalty 7.999999999999999
# training loss 3.2008318500489175
#
#
#
#
#  Iteration: 38
# ['sotto', 'albero', 'giallo']
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 0.8
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 1.6
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 3.2
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 4.0
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 4.8
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 5.6
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: is . you know ? try . try . try . try . try . try . try . try .
# penalty 7.999999999999999
# training loss 3.386971234205844
#
#
#
#
#  Iteration: 39
# ['fronte', 'gatto', 'blu']
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 0.8
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 1.6
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 2.4000000000000004
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 3.2
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 4.0
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 4.8
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 5.6
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 6.3999999999999995
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 7.199999999999999
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try . try .
# penalty 7.999999999999999
# training loss 3.213373395379653
#
#
#
#
#  Iteration: 40
# ['davanti', 'borsa', 'rosso']
# penalize: didn't answer question
# Bot: is the . you say ? ? you say ? ? you say ? ? you say ? ?
# penalty 1
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try .
# penalty 1.8
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try .
# penalty 2.6
# penalize: didn't answer question
# Bot: is the . you say ? ? you say ? ? you say ? ? you say ? ?
# penalty 3.6
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try .
# penalty 4.4
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try .
# penalty 5.2
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try .
# penalty 6.0
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try .
# penalty 6.8
# penalize: didn't answer question
# Bot: is the . you say ? ? you say ? ? you say ? ? you say ? ?
# penalty 7.8
# neutral: did not make a word hint
# Bot: is the . try . try . try . try . try . try . try . try .
# penalty 8.6
# training loss 3.5364811400703324
#
#
#
#
# validation loss 4.123483151110037
#
#
#  Iteration: 41
# ['fronte', 'albero', 'gialla']
# neutral: did not make a word hint
# Bot: the word word for for for for ? try . try the word for for for ? try . try
# penalty 0.8
# neutral: did not make a word hint
# Bot: the word word for for for for ? try . try the word for for for ? try . try
# penalty 1.6
# neutral: did not make a word hint
# Bot: the word word for for for for ? try . try the word for for for ? try . try
# penalty 2.4000000000000004
# penalize: didn't answer question
# Bot: the word word for for for ? you say ? the word word for for ? you say ? the
# penalty 3.4000000000000004
# penalize: didn't answer question
# Bot: the word word for for for ? you say ? the word word for for ? you say ? the
# penalty 4.4
# penalize: didn't answer question
# ...
# penalty 8.2
# penalize: had irrelevent hints
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct
# penalty 9.2
# training loss 1.2579042585258156
#
#
#
#
#  Iteration: 673
# ['accanto', 'coniglio', 'gialla']
# penalize: didn't answer question
# Bot: is next to the . al is next to the . s blu . s
# penalty 1
# penalize: had irrelevent hints
# Bot: yellow is gialla . s in front of the is e dentro la . in italian . the word for bag is
# penalty 2
# penalize: didn't answer question
# Bot: is next to the . al is next to the . s blu . s
# penalty 3
# penalize: didn't answer question
# Bot: is next to the . al is next to the . s blu . s
# penalty 4
# penalize: had irrelevent hints
# Bot: almost the word for box is scatola . is correct . is inside of the is e vicino alla . do you know
# penalty 5
# penalize: didn't answer question
# Bot: is next to the . al is next to the . s blu . s
# penalty 6
# penalize: had irrelevent hints
# Bot: almost the word for box is scatola . is correct . is inside of the is e vicino alla . do you know
# penalty 7
# penalize: didn't answer question
# Bot: is next to the . al is next to the . s blu . s
# penalty 8
# penalize: had irrelevent hints
# Bot: almost the word for box is scatola . is correct . is inside of the is e vicino alla . do you know
# penalty 9
# penalize: had irrelevent hints
# Bot: almost the word for box is scatola . is correct . is inside of the is e vicino alla . do you know
# penalty 10
# training loss 1.5636279122142525
#
#
#
#
#  Iteration: 674
# ['cima', 'letto', 'giallo']
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 1
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 2
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 3
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 4
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 5
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 6
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 7
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 8
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 9
# penalize: student was correct but no confirmation
# Bot: almost . you need to include the color of the box . is correct . is correct . is correct . is correct . is correct . is correct . is correct . is
# penalty 10
# training loss 1.6465950637642155
#
#
#
#
#  Iteration: 675
# ['cima', 'coniglio', 'giallo']
# penalize: didn't answer question
# Bot: is on top of the . is on top of the . is on top of the . is on top of the .
# penalty 1
# penalize: didn't answer question
# Bot: is on top of the . is on top of the . is on top of the . is on top of the .
# penalty 2
# penalize: had irrelevent hints
# Bot: almost . you need to include the color of the tree . s in on the . is correct . is correct . is
# penalty 3
# penalize: had irrelevent hints
# Bot: almost . you need to include the color of the tree . s in on the . is correct . is correct . is
# penalty 4
# penalize: had irrelevent hints
# Bot: almost . you need to include the color of the tree . s in on the . is correct . is correct . is
# penalty 5
# penalize: had irrelevent hints
# Bot: almost . you need to include the color of the tree . s in on the . is correct . is correct . is
# penalty 6
# penalize: had irrelevent hints
# Bot: almost . you need to include the color of the tree . s in on the . is correct . is correct . is
# penalty 7
# penalize: didn't answer question
# Bot: is on top of the . is on top of the . is on top of the . is on top of the .
# penalty 8
# penalize: didn't answer question
# Bot: is on top of the . is on top of the . is on top of the . is on top of the .
# penalty 9
# penalize: had irrelevent hints
# Bot: almost . you need to include the color of the tree . s in on the . is correct . is correct . is
# penalty 10
# training loss 1.5120126083277274
#
#
#
#
#  Iteration: 676
# ['cima', 'cane', 'blu']
# reward: is a hint student got wrong
# Bot: blue is blu . in italian . is on top of the . is on top of the . is on top of the . is
# penalty 0.2
# penalize: had irrelevent hints
# Bot: e dietro la . is on top of the . is on top of the . is on top of the . is on top
# penalty 1.2
# penalize: didn't answer question
# Bot: box is scatola . is the word for box . is the word for box . is the word for box . is the word for box
# penalty 2.2
# penalize: didn't answer question
# Bot: box is scatola . is the word for box . is the word for box . is the word for box . is the word for box
# penalty 3.2
# penalize: didn't answer question
# Bot: box is scatola . is the word for box . is the word for box . is the word for box . is the word for box
# penalty 4.2
# penalize: had irrelevent hints
# Bot: e dietro la . is on top of the . is on top of the . is on top of the . is on top
# penalty 5.2
# penalize: had irrelevent hints
# Bot: e dietro la . is on top of the . is on top of the . is on top of the . is on top
# penalty 6.2
# penalize: didn't answer question
# Bot: box is scatola . is the word for box . is the word for box . is the word for box . is the word for box
# penalty 7.2
# penalize: had irrelevent hints
# Bot: e dietro la . is on top of the . is on top of the . is on top of the . is on top
# penalty 8.2
# penalize: didn't answer question
# Bot: box is scatola . is the word for box . is the word for box . is the word for box . is the word for box
# penalty 9.2
# training loss 1.1523876287113928
#
#
#
#
#  Iteration: 677
# ['accanto', 'scatola', 'rosso']
# reward: is a hint student got wrong
# Bot: box is scatola . is the word for box . is the word for box . is the word for box . is the word for box . is the word for box . is
# penalty 0.2
# penalize: had irrelevent hints
# Bot: red is rossa . is the word for box . is the word for red . s not alla . that the word for box is scatola . is correct . is the word for
# penalty 1.2
# penalize: had irrelevent hints
# Bot: red is rossa . is the word for box . is the word for red . s not alla . that the word for box is scatola . is correct . is the word for
# penalty 2.2
# penalize: had irrelevent hints
# Bot: red is rossa . is the word for box . is the word for red . s not alla . that the word for box is scatola . is correct . is the word for
# penalty 3.2
# penalize: had irrelevent hints
# Bot: red is rossa . is the word for box . is the word for red . s not alla . that the word for box is scatola . is correct . is the word for
# penalty 4.2
# penalize: had irrelevent hints
# Bot: red is rossa . is the word for box . is the word for red . s not alla . that the word for box is scatola . is correct . is the word for
# penalty 5.2
# penalize: had irrelevent hints
# Bot: red is rossa . is the word for box . is the word for red . s not alla . that the word for box is scatola . is correct . is the word for
# penalty 6.2
# penalize: had irrelevent hints
# Bot: red is rossa . is the word for box . is the word for red . s not alla . that the word for box is scatola . is correct . is the word for
# penalty 7.2
# penalize: had irrelevent hints
# Bot: red is rossa . is the word for box . is the word for red . s not alla . that the word for box is scatola . is correct . is the word for
# penalty 8.2
# penalize: had irrelevent hints
# Bot: red is rossa . is the word for box . is the word for red . s not alla . that the word for box is scatola . is correct . is the word for
# penalty 9.2
# training loss 1.5560342968873433
#
#
#
#
#  Iteration: 678
# ['fronte', 'scatola', 'giallo']
# penalize: had irrelevent hints
# Bot: yellow is gialla . s in front of the . . in italian . the noun before the adjective . try again .
# penalty 1
# reward: answered question
# Bot: box is scatola . is the word for box . is the word for box . is the word for box . is the word for box
# penalty 1.2
# neutral: did not make a word hint
# Bot: that s right . can you put it together now ? that is correct . in italian . is correct . in italian . is
# penalty 2.0
# neutral: did not make a word hint
# Bot: that s right . can you put it together now ? that is correct . in italian . is correct . in italian . is
# penalty 2.8
# neutral: did not make a word hint
# Bot: that s right . can you put it together now ? that is correct . in italian . is correct . in italian . is
# penalty 3.5999999999999996
# neutral: did not make a word hint
# Bot: that s right . can you put it together now ? that is correct . in italian . is correct . in italian . is
# penalty 4.3999999999999995
# neutral: did not make a word hint
# Bot: that s right . can you put it together now ? that is correct . in italian . is correct . in italian . is
# penalty 5.199999999999999
# neutral: did not make a word hint
# Bot: that s right . can you put it together now ? that is correct . in italian . is correct . in italian . is
# penalty 5.999999999999999
# neutral: did not make a word hint
# Bot: that s right . can you put it together now ? that is correct . in italian . is correct . in italian . is
# penalty 6.799999999999999
# neutral: did not make a word hint
# Bot: that s right . can you put it together now ? that is correct . in italian . is correct . in italian . is
# penalty 7.599999999999999
# training loss 1.002511277954217
#
#
#
#
#  Iteration: 679
# ['fronte', 'scatola', 'blu']
# penalize: didn't answer question
# Bot: you need to say is in front of the . is the word for box . is the word for box . is the word for
# penalty 1
# penalize: didn't answer question
# Bot: you need to say is in front of the . is the word for box . is the word for box . is the word for
# penalty 2
# penalize: didn't answer question
# Bot: you need to say is in front of the . is the word for box . is the word for box . is the word for
# penalty 3
# penalize: not a hint that student got wrong
# Bot: you need to say la scatola not just scatola . s blu . that is correct . in italian . is correct . is
# penalty 4
# penalize: student was correct but no confirmation
# Bot: that s right . can you try again ? that is correct . in italian . is correct . is correct . is
# penalty 5
# penalize: student was correct but no confirmation
# Bot: that s right . can you try again ? that is correct . in italian . is correct . is correct . is
# penalty 6
# penalize: student was correct but no confirmation
# Bot: that s right . can you try again ? that is correct . in italian . is correct . is correct . is
# penalty 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-4a304288c18b> in <module>
#      67     #train one iter
#      68
# ---> 69     returned_loss, tutor_score = train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding, encoder_optimizer, decoder_optimizer, small_batch_size, iteration, clip)
#      70
#      71     returned_losses.append(returned_loss)
#
# <ipython-input-23-505317189841> in train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip, i)
#      42
#      43     searcher = GreedySearchDecoder(encoder, decoder)
# ---> 44     tutor_score = simulate_with_student(encoder, decoder, searcher, voc)
#      45     encoder.train()
#      46     decoder.train()
#
# <ipython-input-20-9e5675ca972e> in simulate_with_student(encoder, decoder, searcher, voc)
#      30
#      31         #evaluate on model
# ---> 32         output_words,scores = evaluateInput(encoder, decoder, searcher, voc, input_sent, max_target_len)
#      33         output = ' '.join(output_words)
#      34         #evaluate on input
#
# <ipython-input-16-7211210f7d7a> in evaluateInput(encoder, decoder, searcher, voc, input_sentence, max_length)
#      21     input_sentence = normalizeString(input_sentence)
#      22     # Evaluate sentence
# ---> 23     output_words, scores = evaluate(encoder, decoder, searcher, voc, input_sentence, max_length)
#      24     # Format and print response sentence
#      25     output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
#
# <ipython-input-16-7211210f7d7a> in evaluate(encoder, decoder, searcher, voc, sentence, max_length)
#      11     lengths = lengths.to(device)
#      12     # Decode sentence with searcher
# ---> 13     tokens, scores = searcher(input_batch, lengths, max_length)
#      14     # indexes -> words
#      15     decoded_words = [voc.index2word[token.item()] for token in tokens]
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-15-d393f84f21eb> in forward(self, input_seq, input_length, max_length)
#      18         for _ in range(max_length):
#      19             # Forward pass through decoder
# ---> 20             decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
#      21             # Obtain most likely word token and its softmax score
#      22             decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-14-6ea60ef8f190> in forward(self, input_step, last_hidden, encoder_outputs)
#      25         embedded = self.embedding_dropout(embedded)
#      26         # Forward through unidirectional GRU
# ---> 27         rnn_output, hidden = self.gru(embedded, last_hidden)
#      28         # Calculate attention weights from the current GRU output
#      29         attn_weights = self.attn(rnn_output, encoder_outputs)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     209         if batch_sizes is None:
#     210             result = _impl(input, hx, self._get_flat_weights(), self.bias, self.num_layers,
# --> 211                            self.dropout, self.training, self.bidirectional, self.batch_first)
#     212         else:
#     213             result = _impl(input, batch_sizes, hx, self._get_flat_weights(), self.bias,
#
# KeyboardInterrupt:

# %% [markdown]
# EVALUATION on validation set

# %%
TEST_SIZE = 30

encoder.eval()
decoder.eval()

searcher = GreedySearchDecoder(encoder, decoder)

evaluate_with_target(encoder, decoder, searcher, voc, TEST_SIZE, INPUT_SIZE)
